# %%
# Importamos las bibliotecas necesarias
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# Definimos la longitud deseada, en este caso, 4
length = 4

# Cargamos el conjunto de datos desde un archivo CSV
df = pd.read_csv('c:/datos/Dataset_Regresion_Lineal.csv', index_col=False, header=0)

# Extraemos las columnas 'metro' y 'precio' como variables independientes (x) y dependientes (y)
x = df.metro.values
y = df.precio.values

# Reshape the 1D array to a 2D array with the correct shape
x = x.reshape(-1, 1)

# Dividimos los datos en conjuntos de entrenamiento y prueba con un tamaño de prueba de 3 muestras
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.75)

# Realizamos una regresión lineal con regularización
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

# Evaluamos la precisión del modelo en el conjunto de prueba
score = regr.score(x_test, y_test)
print("Precisión del modelo en el conjunto de prueba:", score)
# Out:
# Precisión del modelo en el conjunto de prueba: -0.005081515985602358

# %%
# Graficamos los datos y la línea de regresión
plt.scatter(x_test, y_test, color='green')
plt.plot(x_test, regr.predict(x_test), color='black')
plt.xlabel('Metros cuadrados', fontsize=16)
plt.ylabel('Precio', fontsize=16)
plt.legend(['Datos', 'Regresión lineal'], loc='upper left')
plt.show()
